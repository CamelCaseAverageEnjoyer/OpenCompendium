.03333333333333333, 0.03333333333333333, 0.03333333333333333, 0.03333333333333333], [], [], [0.0305, 0.036166666666666666, 0.036166666666666666, 0.0305], [0.0305, 0.036166666666666666, 0.036166666666666666, 0.0305], [0.0305, 0.0305, 0.0305, 0.0305], [0.036166666666666666, 0.036166666666666666, 0.036166666666666666, 0.036166666666666666], [0.0305, 0.0305, 0.036166666666666666, 0.036166666666666666], [0.0305, 0.0305, 0.036166666666666666, 0.036166666666666666], [-0.036166666666666666, -0.0305, -0.0305, -0.036166666666666666], [-0.036166666666666666, -0.0305, -0.0305, -0.036166666666666666], [-0.036166666666666666, -0.036166666666666666, -0.036166666666666666, -0.036166666666666666], [-0.0305, -0.0305, -0.0305, -0.0305], [-0.036166666666666666, -0.036166666666666666, -0.0305, -0.0305], [-0.036166666666666666, -0.036166666666666666, -0.0305, -0.0305], [0.0305, 0.036166666666666666, 0.036166666666666666, 0.0305], [0.0305, 0.036166666666666666, 0.036166666666666666, 0.0305], [0.0305, 0.0305, 0.0305, 0.0305], [0.036166666666666666, 0.036166666666666666, 0.036166666666666666, 0.036166666666666666], [0.0305, 0.0305, 0.036166666666666666, 0.036166666666666666], [0.0305, 0.0305, 0.036166666666666666, 0.036166666666666666], [-0.036166666666666666, -0.0305, -0.0305, -0.036166666666666666], [-0.036166666666666666, -0.0305, -0.0305, -0.036166666666666666], [-0.036166666666666666, -0.036166666666666666, -0.036166666666666666, -0.036166666666666666], [-0.0305, -0.0305, -0.0305, -0.0305], [-0.036166666666666666, -0.036166666666666666, -0.0305, -0.0305], [-0.036166666666666666, -0.036166666666666666, -0.0305, -0.0305]], [[], [], [], [], [-0.03783333333333333, -0.03783333333333333, -0.03783333333333333, -0.03783333333333333], [0.03783333333333333, 0.03783333333333333, 0.03783333333333333, 0.03783333333333333], [-0.04016666666666667, -0.04016666666666667, 0.04016666666666667, 0.04016666666666667], [-0.04016666666666667, -0.04016666666666667, 0.04016666666666667, 0.04016666666666667], [-0.04016666666666667, -0.04016666666666667, 0.04016666666666667, 0.04016666666666667], [-0.04016666666666667, -0.04016666666666667, 0.04016666666666667, 0.04016666666666667], [-0.04016666666666667, -0.04016666666666667, -0.04016666666666667, -0.04016666666666667], [0.04016666666666667, 0.04016666666666667, 0.04016666666666667, 0.04016666666666667], [-0.04016666666666667, -0.04016666666666667, 0.04016666666666667, 0.04016666666666667], [-0.04016666666666667, -0.04016666666666667, 0.04016666666666667, 0.04016666666666667], [-0.04016666666666667, -0.04016666666666667, 0.04016666666666667, 0.04016666666666667], [-0.04016666666666667, -0.04016666666666667, 0.04016666666666667, 0.04016666666666667], [-0.04016666666666667, -0.04016666666666667, -0.04016666666666667, -0.04016666666666667], [0.04016666666666667, 0.04016666666666667, 0.04016666666666667, 0.04016666666666667], [-0.04016666666666667, -0.04016666666666667, 0.04016666666666667, 0.04016666666666667], [-0.04016666666666667, -0.04016666666666667, 0.04016666666666667, 0.04016666666666667], [-0.04016666666666667, -0.04016666666666667, 0.04016666666666667, 0.04016666666666667], [-0.04016666666666667, -0.04016666666666667, 0.04016666666666667, 0.04016666666666667], [-0.04016666666666667, -0.04016666666666667, -0.04016666666666667, -0.04016666666666667], [0.04016666666666667, 0.04016666666666667, 0.04016666666666667, 0.04016666666666667], [-0.04016666666666667, -0.04016666666666667, 0.04016666666666667, 0.04016666666666667], [-0.04016666666666667, -0.04016666666666667, 0.04016666666666667, 0.04016666666666667], [-0.04016666666666667, -0.04016666666666667, 0.04016666666666667, 0.04016666666666667], [-0.04016666666666667, -0.04016666666666667, 0.04016666666666667, 0.04016666666666667], [-0.04016666666666667, -0.04016666666666667, -0.04016666666666667, -0.04016666666666667], [0.04016666666666667, 0.04016666666666667, 0.04016666666666667, 0.04016666666666667]]]

# %% [markdown]
# <u>Сравнить матрицы в Matlab</u>

# %%
import clipboard
text = input()
text = text.replace("[[", "[")
text = text.replace("]]", "]")
text = text.replace("], [", "; ")
clipboard.copy(text)
print(f"\n{text}")

# %% [markdown]
# <u>Ручная проверка на вшивость</u>

# %%
from sympy import *
x, y, z, ax, ay, az = var('x y z a_x a_y a_z')
G = (((ay*x)/((x)**2 + (y)**2 + (z)**2)**(1/2) - (ax*y)/((x)**2 + (y)**2 + (z)**2)**(1/2))**2 + ((az*x)/((x)**2 + (y)**2 + (z)**2)**(1/2) - (ax*z)/((x)**2 + (y)**2 + (z)**2)**(1/2))**2 + ((az*y)/((x)**2 + (y)**2 + (z)**2)**(1/2) - (ay*z)/((x)**2 + (y)**2 + (z)**2)**(1/2))**2)**(3/2);
display(G.subs([(ax, 1), (ay, 0), (az, 0)]))
display(G.subs([(ax, 0), (ay, 1), (az, 0)]))
display(G.subs([(ax, 0), (ay, 0), (az, 1)]))
# Out:
# (y**2/(x**2 + y**2 + z**2)**1.0 + z**2/(x**2 + y**2 + z**2)**1.0)**1.5
# (x**2/(x**2 + y**2 + z**2)**1.0 + z**2/(x**2 + y**2 + z**2)**1.0)**1.5
# (x**2/(x**2 + y**2 + z**2)**1.0 + y**2/(x**2 + y**2 + z**2)**1.0)**1.5

# %%
from common_func import *

o, num_params, t, ω, μ, ρ, r_orb, v_orb = init_symbol_params()
G1 = kf.local_dipole(v=o.v, r=Matrix([x,y,z]), ind='x')
display(G1)
G2 = kf.local_dipole(v=o.v, r=Matrix([x,y,z]), ind='y')
display(G2)
G3 = kf.local_dipole(v=o.v, r=Matrix([x,y,z]), ind='y')
display(G3)
# Out:
# Параметры не могут быть загружены! Нет файла: kiamformation/data/config_choose.csv
# Матрицы Ф:(6, 6), Q:(3, 3), P:(6, 6), D:(6, 3)
# Высота орбиты: 400 км
# Период орбиты: 1.54 часов
# Плотность атмосферы: 6.404751331738951e-12 кг/м³
# (y**2/(x**2 + y**2 + z**2) + z**2/(x**2 + y**2 + z**2))**(3/2)
# (x**2/(x**2 + y**2 + z**2) + z**2/(x**2 + y**2 + z**2))**(3/2)
# (x**2/(x**2 + y**2 + z**2) + z**2/(x**2 + y**2 + z**2))**(3/2)

# %% [markdown]
# **Так, G хотя бы одинаковый...**

# %%
z1 = G1 / (x**2 + y**2 + z**2)
H3_00 = z1.diff(x)
display(H3_00)
display(H3_00.subs([(x, 10), (y, 20), (z, 30)]))
print(float(H3_00.subs([(x, 10), (y, 20), (z, 30)])))
# Out:
# -2*x*(y**2/(x**2 + y**2 + z**2) + z**2/(x**2 + y**2 + z**2))**(3/2)/(x**2 + y**2 + z**2)**2 + sqrt(y**2/(x**2 + y**2 + z**2) + z**2/(x**2 + y**2 + z**2))*(-3*x*y**2/(x**2 + y**2 + z**2)**2 - 3*x*z**2/(x**2 + y**2 + z**2)**2)/(x**2 + y**2 + z**2)
# -13*sqrt(182)/7683200
# -2.2826372907384494e-05

# %%
H1 = (3*(abs((ay*x)/(abs(x)**2 + abs(y)**2 + abs(z)**2)**(1/2) - (ax*y)/(abs(x)**2 + abs(y)**2 + abs(z)**2)**(1/2))**2 + abs((az*x)/(abs(x)**2 + abs(y)**2 + abs(z)**2)**(1/2) - (ax*z)/(abs(x)**2 + abs(y)**2 + abs(z)**2)**(1/2))**2 + abs((az*y)/(abs(x)**2 + abs(y)**2 + abs(z)**2)**(1/2) - (ay*z)/(abs(x)**2 + abs(y)**2 + abs(z)**2)**(1/2))**2)**(1/2)*(2*abs((ay*x)/(abs(x)**2 + abs(y)**2 + abs(z)**2)**(1/2) - (ax*y)/(abs(x)**2 + abs(y)**2 + abs(z)**2)**(1/2))*sign((ay*x)/(abs(x)**2 + abs(y)**2 + abs(z)**2)**(1/2) - (ax*y)/(abs(x)**2 + abs(y)**2 + abs(z)**2)**(1/2))*(ay/(abs(x)**2 + abs(y)**2 + abs(z)**2)**(1/2) - (ay*x*abs(x)*sign(x))/(abs(x)**2 + abs(y)**2 + abs(z)**2)**(3/2) + (ax*y*abs(x)*sign(x))/(abs(x)**2 + abs(y)**2 + abs(z)**2)**(3/2)) - 2*abs((az*y)/(abs(x)**2 + abs(y)**2 + abs(z)**2)**(1/2) - (ay*z)/(abs(x)**2 + abs(y)**2 + abs(z)**2)**(1/2))*sign((az*y)/(abs(x)**2 + abs(y)**2 + abs(z)**2)**(1/2) - (ay*z)/(abs(x)**2 + abs(y)**2 + abs(z)**2)**(1/2))*((az*y*abs(x)*sign(x))/(abs(x)**2 + abs(y)**2 + abs(z)**2)**(3/2) - (ay*z*abs(x)*sign(x))/(abs(x)**2 + abs(y)**2 + abs(z)**2)**(3/2)) + 2*abs((az*x)/(abs(x)**2 + abs(y)**2 + abs(z)**2)**(1/2) - (ax*z)/(abs(x)**2 + abs(y)**2 + abs(z)**2)**(1/2))*sign((az*x)/(abs(x)**2 + abs(y)**2 + abs(z)**2)**(1/2) - (ax*z)/(abs(x)**2 + abs(y)**2 + abs(z)**2)**(1/2))*(az/(abs(x)**2 + abs(y)**2 + abs(z)**2)**(1/2) - (az*x*abs(x)*sign(x))/(abs(x)**2 + abs(y)**2 + abs(z)**2)**(3/2) + (ax*z*abs(x)*sign(x))/(abs(x)**2 + abs(y)**2 + abs(z)**2)**(3/2))))/(2*(x**2 + y**2 + z**2)) - (2*x*(abs((ay*x)/(abs(x)**2 + abs(y)**2 + abs(z)**2)**(1/2) - (ax*y)/(abs(x)**2 + abs(y)**2 + abs(z)**2)**(1/2))**2 + abs((az*x)/(abs(x)**2 + abs(y)**2 + abs(z)**2)**(1/2) - (ax*z)/(abs(x)**2 + abs(y)**2 + abs(z)**2)**(1/2))**2 + abs((az*y)/(abs(x)**2 + abs(y)**2 + abs(z)**2)**(1/2) - (ay*z)/(abs(x)**2 + abs(y)**2 + abs(z)**2)**(1/2))**2)**(3/2))/(x**2 + y**2 + z**2)**2
H1_00 = H1.subs([(ax, 1), (ay, 0), (az, 0)])
display(H1_00)
display(H1_00.subs([(x, 10), (y, 20), (z, 30)]))
print(float(H1_00.subs([(x, 10), (y, 20), (z, 30)])))
# display(H1.subs([(ax, 0), (ay, 1), (az, 0)]))
# display(H1.subs([(ax, 0), (ay, 0), (az, 1)]))
# Out:
# -2*x*(Abs(y)**2/(Abs(x)**2 + Abs(y)**2 + Abs(z)**2)**1.0 + Abs(z)**2/(Abs(x)**2 + Abs(y)**2 + Abs(z)**2)**1.0)**1.5/(x**2 + y**2 + z**2)**2 + 3*(Abs(y)**2/(Abs(x)**2 + Abs(y)**2 + Abs(z)**2)**1.0 + Abs(z)**2/(Abs(x)**2 + Abs(y)**2 + Abs(z)**2)**1.0)**0.5*(-2*y*Abs(x)*Abs(y)*sign(x)*sign(y/(Abs(x)**2 + Abs(y)**2 + Abs(z)**2)**0.5)/(Abs(x)**2 + Abs(y)**2 + Abs(z)**2)**2.0 - 2*z*Abs(x)*Abs(z)*sign(x)*sign(z/(Abs(x)**2 + Abs(y)**2 + Abs(z)**2)**0.5)/(Abs(x)**2 + Abs(y)**2 + Abs(z)**2)**2.0)/(2*x**2 + 2*y**2 + 2*z**2)
# -2.28263729073845e-5
# -2.2826372907384494e-05

# %%
r_d, v_d, q_d, ω_d = get_state_vector(func=kf.get_func, obj='d', n=1)
r_c, v_c, q_c, ω_c = get_state_vector(func=kf.get_func, obj='c', n=1)
o.v.GAIN_MODEL_C_N = 3
o.v.GAIN_MODEL_F_N = 0
o.v.init_choice_params()
o.c.gain_mode = o.v.GAIN_MODEL_C = "3 antennas"
o.f.gain_mode = o.v.GAIN_MODEL_F = "isotropic"
o.c.n = 1
o.f.n = 1
o.v.NAVIGATION_ANGLES = False
o.v.DYNAMIC_MODEL['aero drag'] = False
o.v.MULTI_ANTENNA_TAKE = True
o.v.MULTI_ANTENNA_SEND = True
o.f.r_orf, o.f.v_orf, o.f.q, o.f.w_brf = r_d, v_d, q_d, ω_d
q_c = [kf.q_dot(Matrix([sin(o.v.W_ORB*t/2), 0, cos(o.v.W_ORB*t/2), 0]), Matrix((1/2, -1/2, -1/2, -1/2)))]
o.c.r_orf, o.c.v_orf, o.c.q, o.c.w_brf = [Matrix([0,0,0])], v_c, q_c, ω_c
H2 = kf.h_matrix(t=t, v=o.v, f=o.f, c=o.c, r_f=r_d, r_c=[Matrix([0,0,0])], 
                          q_f=[Matrix(q_d[i][1:4]) for i in range(o.f.n)], q_c=[Matrix((-1/2, -1/2, -1/2)) for i in range(o.c.n)])
H2_00 = H2[0,0]
display(H2_00)
display(H2_00.subs([(o.f.r_orf[0][0], 10), (o.f.r_orf[0][1], 20), (o.f.r_orf[0][2], 30), (t, 0)]))
print(float(H2_00.subs([(o.f.r_orf[0][0], 10), (o.f.r_orf[0][1], 20), (o.f.r_orf[0][2], 30), (t, 0)])))
# Out:
# sqrt(r_0^d_y(t)**2/(r_0^d_x(t)**2 + r_0^d_y(t)**2 + r_0^d_z(t)**2) + r_0^d_z(t)**2/(r_0^d_x(t)**2 + r_0^d_y(t)**2 + r_0^d_z(t)**2))*(-3*r_0^d_x(t)*r_0^d_y(t)**2/(r_0^d_x(t)**2 + r_0^d_y(t)**2 + r_0^d_z(t)**2)**2 - 3*r_0^d_x(t)*r_0^d_z(t)**2/(r_0^d_x(t)**2 + r_0^d_y(t)**2 + r_0^d_z(t)**2)**2)/(r_0^d_x(t)**2 + r_0^d_y(t)**2 + r_0^d_z(t)**2) - 2*(r_0^d_y(t)**2/(r_0^d_x(t)**2 + r_0^d_y(t)**2 + r_0^d_z(t)**2) + r_0^d_z(t)**2/(r_0^d_x(t)**2 + r_0^d_y(t)**2 + r_0^d_z(t)**2))**1.5*r_0^d_x(t)/(r_0^d_x(t)**2 + r_0^d_y(t)**2 + r_0^d_z(t)**2)**2
# -39*sqrt(182)/38416000 - 9.1305491629538e-6
# -2.2826372907384494e-05

# %% [markdown]
# **А ВОТ МАТРИЦА H РАЗНАЯ**<br>
# а че с измерениями

# %%
# В коде
y111, notes = kf.measure_antennas_power(c=o.c, f=o.f, v=o.v, p=o.p, j=len(r_d), estimated_params=r_d, t=t)
y111[0]
# Out:
# ((-(-1.0*((-1.0*sin(t*w_0/2) - 1.0*cos(t*w_0/2))*(-0.5*sin(t*w_0/2) + 0.5*cos(t*w_0/2)) - (-1.0*sin(t*w_0/2) + 1.0*cos(t*w_0/2))*(0.5*sin(t*w_0/2) + 0.5*cos(t*w_0/2)))*sin(t*w_0) + 1.0*(-0.5*(-sin(t*w_0/2) - cos(t*w_0/2))**2 - 0.5*(-sin(t*w_0/2) + cos(t*w_0/2))**2 + 1)*cos(t*w_0))*r_0^d_x(t) - (1.0*((-1.0*sin(t*w_0/2) - 1.0*cos(t*w_0/2))*(-0.5*sin(t*w_0/2) + 0.5*cos(t*w_0/2)) - (-1.0*sin(t*w_0/2) + 1.0*cos(t*w_0/2))*(0.5*sin(t*w_0/2) + 0.5*cos(t*w_0/2)))*cos(t*w_0) + 1.0*(-0.5*(-sin(t*w_0/2) - cos(t*w_0/2))**2 - 0.5*(-sin(t*w_0/2) + cos(t*w_0/2))**2 + 1)*sin(t*w_0))*r_0^d_z(t) - (1.0*(-1.0*sin(t*w_0/2) - 1.0*cos(t*w_0/2))*(0.5*sin(t*w_0/2) + 0.5*cos(t*w_0/2)) + 1.0*(-1.0*sin(t*w_0/2) + 1.0*cos(t*w_0/2))*(-0.5*sin(t*w_0/2) + 0.5*cos(t*w_0/2)))*r_0^d_y(t))**2/((-(-1.0*(1 - 1.0*(-sin(t*w_0/2) + cos(t*w_0/2))**2)*sin(t*w_0) + 1.0*((-1.0*sin(t*w_0/2) - 1.0*cos(t*w_0/2))*(-0.5*sin(t*w_0/2) + 0.5*cos(t*w_0/2)) + (-1.0*sin(t*w_0/2) + 1.0*cos(t*w_0/2))*(0.5*sin(t*w_0/2) + 0.5*cos(t*w_0/2)))*c
# ...

# %%
# Как должно быть
z1
# Out:
# (y**2/(x**2 + y**2 + z**2) + z**2/(x**2 + y**2 + z**2))**(3/2)/(x**2 + y**2 + z**2)

# %% [markdown]
# а че с гейном

# %%
Gmy1 = kf.get_gain(v=o.v, obj=o.c, r=Matrix([x,y,z]), if_take=False, if_send=True)
for g in Gmy1:
    display(g)
# Out:
# (y**2/(x**2 + y**2 + z**2) + z**2/(x**2 + y**2 + z**2))**(3/2)
# (x**2/(x**2 + y**2 + z**2) + z**2/(x**2 + y**2 + z**2))**(3/2)
# (x**2/(x**2 + y**2 + z**2) + y**2/(x**2 + y**2 + z**2))**(3/2)
